# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\afeki\Desktop\Code\AdavancedRecoSystems\HW1\elbow.csv')
df = df[df.columns[1:]]
df
# Out:
#     train_accuracy_4  test_accuracy_4  train_accuracy_6  test_accuracy_6  \
# 0           0.921135         0.975716          0.915172         0.972862
# 1           0.904406         0.962140          0.903121         0.961956
# 2           0.898808         0.958148          0.898017         0.958198
# 3           0.895296         0.957906          0.893622         0.957882
# 4           0.890865         0.958339          0.886757         0.954598
# 5           0.884104         0.955698          0.875464         0.951026
# 6           0.875144         0.954232          0.863579         0.946718
# 7           0.867105         0.950912          0.853016         0.937912
# 8           0.860209         0.944877          0.844042         0.935132
# 9           0.854061         0.943126          0.837004         0.931420
# 10          0.848745         0.938540          0.830812         0.927178
# 11          0.844080         0.935303          0.825629         0.923679
# ...

# %%
# np.linalg.norm(df.values, axis = 1)
np.square(df.values).sum()
# Out:
# 24.873356568492532

# %%
test_cols = [f"test_accuracy_{n}" for n in list(range(4,32,2))] 
df[test_cols].plot(figsize = (20,10))

# %%
df[test_cols].iloc[19,:].plot(figsize = (10,5))

# %%
df[test_cols].iloc[12,:].plot(figsize = (10,5))

# %%
for n in ):
  
  temp_df = results_df[cols]
  temp_df.columns =  suffixes 
  plt.figure()
  temp_df.astype(float).plot(title= F"Train & Test accuracys for {exp}")
  if SAVE_FIGS:
    plt.savefig(graphs_dir+ F"/{exp}.png")

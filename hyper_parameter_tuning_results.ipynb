# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import skopt
from skopt import load
import pandas as pd
# Out:
# C:\Users\afeki\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# # SGD

# %%
res = load(r"HW1/HyperParamResult_sgd.pkl")
sgd_results = pd.DataFrame(res.x_iters, columns = ['lr','l2_users','l2_items','l2_users_bias','l2_items_bias','hidden_dimension_size'])
sgd_results['result'] = res.func_vals 
sgd_results.style.bar(subset=['result'], align='mid', color=['#d65f5f'])
# Out:
# <style  type="text/css" >
#     #T_fd0abefa_1bff_11ea_82d0_9c305b77d51erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 91.4%, transparent 91.4%);
#         }    #T_fd0abefa_1bff_11ea_82d0_9c305b77d51erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.8%, transparent 99.8%);
#         }    #T_fd0abefa_1bff_11ea_82d0_9c305b77d51erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_fd0abefa_1bff_11ea_82d0_9c305b77d51erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.8%, transparent 98.8%);
#         }    #T_fd0abefa_1bff_11ea_82d0_9c305b77d51erow4_col6 {
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# # ALS

# %%
res = load(r"HW1/HyperParamResult_sgd.pkl")
sgd_results = pd.DataFrame(res.x_iters, columns = ['lr','l2_users','l2_items','l2_users_bias','l2_items_bias','hidden_dimension_size'])
sgd_results['result'] = res.func_vals 
sgd_results.style.bar(subset=['result'], align='mid', color=['#d65f5f'])
# Out:
# <style  type="text/css" >
#     #T_24f62af4_1c00_11ea_b9ad_9c305b77d51erow0_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 91.4%, transparent 91.4%);
#         }    #T_24f62af4_1c00_11ea_b9ad_9c305b77d51erow1_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.8%, transparent 99.8%);
#         }    #T_24f62af4_1c00_11ea_b9ad_9c305b77d51erow2_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_24f62af4_1c00_11ea_b9ad_9c305b77d51erow3_col6 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.8%, transparent 98.8%);
#         }    #T_24f62af4_1c00_11ea_b9ad_9c305b77d51erow4_col6 {
#             width:  10em;
#              height:  80%;
# ...
